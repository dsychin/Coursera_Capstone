# %% [markdown]
# # Coursera IBM Data Science Professional Specialization Capstone Project

# %% [markdown]
# ## Description
# This notebook will be used to complete the final capstone project.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ## Scrape Wikipedia for Toronto neighbourhoods

# %%
# Install BeautifulSoup
# !conda install -c anaconda beautifulsoup4 --yes

# %%
from bs4 import BeautifulSoup
import requests

r = requests.get("https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto")
soup = BeautifulSoup(r.content)

# %%
# Check that we have the right page
print(soup.title)
# Out:
# <title>List of neighbourhoods in Toronto - Wikipedia</title>

# %%
# Get coordinates for a neighbourhood
# Returns a LatLng array
def get_coordinates(neighbourhood):
    base_uri = 'https://en.wikipedia.org'
    r_neigh = requests.get(base_uri + neighbourhood.a['href'])
    soup_neigh = BeautifulSoup(r_neigh.content)
    
    # Get latitude
    try:
        lat = soup_neigh.find('span', class_='latitude').get_text()
    except:
        lat = None
    
    # Get longitude
    try:
        lng = soup_neigh.find('span', class_='longitude').get_text()
    except:
        lng = None
    
    return [lat, lng]

# Build dataframe
column_names = ['District', 'Neighbourhood', 'Latitude', 'Longitude']
neigh = pd.DataFrame(columns=column_names)

# Iterate through districts
for district in soup.find_all('h3'):
    # Get district name
    heading = district.find('span', class_='mw-headline')
    if heading is None:
        break
    district_name = heading.get_text()
    print('Getting data for {}'.format(district_name))
    
    # Get neighbourhoods in district
    for neighbourhood in district.find_next_sibling('div', class_=None).table.find_all('li'):        
        lat_lng = get_coordinates(neighbourhood)
        neighbourhood_name = neighbourhood.get_text()
        neigh = neigh.append({'District': district_name,
                              'Neighbourhood': neighbourhood_name,
                              'Latitude': lat_lng[0],
                              'Longitude': lat_lng[1]}, ignore_index=True)

neigh
# Out:
# Getting data for Old Toronto
# Getting data for East York
# Getting data for Etobicoke
# Getting data for North York
# Getting data for Scarborough
# Getting data for York
#         District                                      Neighbourhood  \
# 0    Old Toronto                                     Alexandra Park
# 1    Old Toronto                                          The Annex
# 2    Old Toronto                                    Baldwin Village
# 3    Old Toronto                                        Cabbagetown
# 4    Old Toronto                                          CityPlace
# 5    Old Toronto                                          Chinatown
# 6    Old Toronto                               Church and Wellesley
# 7    Old Toronto                                           Corktown
# 8    Old Toronto                                 Discovery District
# 9    Old Toronto                                Distillery District
# 10   Old Toronto                         The Entertainment District
# 11   Old Toronto                                      East Bayfront
# 12   Old Toronto                                   Fashion District
# 13   Old Toronto                                 Financial District
# 14   Old Toronto                                    Garden District
# 15   Old Toronto                                        Grange Park
# 16   Old Toronto                                    Harbord Village
# 17   Old Toronto                                       Harbourfront
# 18   Old Toronto                                  Kensington Market
# 19   Old Toronto                                    Little Japan[5]
# 20   Old Toronto                                          Moss Park
# 21   Old Toronto                                           Old Town
# 22   Old Toronto                                           Quayside
# 23   Old Toronto                                  Queen Street West
# 24   Old Toronto                                        Regent Park
# 25   Old Toronto                                         South Core
# 26   Old Toronto                                     St. James Town
# 27   Old Toronto                                       St. Lawrence
# 28   Old Toronto                                    Toronto Islands
# 29   Old Toronto                                      Trefann Court
# ..           ...                                                ...
# 182  Scarborough                                            Malvern
# 183  Scarborough                                           Maryvale
# 184  Scarborough                                           Milliken
# 185  Scarborough                                        Morningside
# 186  Scarborough                                Morningside Heights
# 187  Scarborough                                           Oakridge
# 188  Scarborough                Port Union (Centennial Scarborough)
# 189  Scarborough                                              Rouge
# 190  Scarborough                            Scarborough City Centre
# 191  Scarborough                               Scarborough Junction
# 192  Scarborough                                Scarborough Village
# 193  Scarborough                                            Steeles
# 194  Scarborough                           Tam O'Shanter – Sullivan
# 195  Scarborough                                          West Hill
# 196  Scarborough                                         West Rouge
# 197  Scarborough                                            Wexford
# 198  Scarborough                                             Woburn
# 199         York                                         Baby Point
# 200         York                               Briar Hill–Belgravia
# 201         York                     Eglinton West (Little Jamaica)
# 202         York                      Fairbank (Caledonia–Fairbank)
# 203         York                                 Humewood–Cedarvale
# 204         York                                            Lambton
# 205         York                                       Mount Dennis
# 206         York  Oakwood–Vaughan (Oakwood Village; Five Points;...
# 207         York                                           Old Mill
# 208         York                                  Rockcliffe–Smythe
# 209         York                           Silverthorn (Keelesdale)
# 210         York                                          Tichester
# 211         York                                             Weston
#
#            Latitude       Longitude
# 0           43°39′N         79°24′W
# 1        43°40′12″N      79°24′14″W
# 2        43°39′22″N      79°23′36″W
# 3        43°39′59″N      79°21′46″W
# 4        43°38′24″N      79°23′43″W
# 5        43°39′10″N      79°23′53″W
# 6     43°39′56.50″N   79°22′51.44″W
# 7        43°39′20″N      79°21′35″W
# 8        43°39′29″N      79°23′17″W
# 9              None            None
# 10             None            None
# 11       43°38′42″N      79°21′53″W
# 12       43°38′42″N      79°23′53″W
# 13   43°38′52.565″N  79°22′54.308″W
# 14       43°39′31″N      79°22′33″W
# 15       43°39′11″N      79°23′35″W
# 16       43°39′40″N      79°24′22″W
# 17       43°38′17″N      79°23′06″W
# 18    43°39′17.18″N   79°24′02.44″W
# 19             None            None
# 20       43°39′21″N      79°22′02″W
# 21       43°39′05″N      79°22′04″W
# 22       43°38′49″N      79°21′42″W
# 23       43°38′59″N      79°23′33″W
# 24       43°39′42″N      79°21′54″W
# 25       43°38′38″N      79°22′46″W
# 26        43°40′9″N      79°22′22″W
# 27       43°38′56″N      79°22′19″W
# 28       43°37′15″N      79°22′43″W
# 29       43°39′24″N      79°21′43″W
# ..              ...             ...
# 182      43°48′42″N      79°13′52″W
# 183      43°44′35″N      79°18′16″W
# 184      43°49′33″N       79°18′3″W
# 185      43°47′13″N      79°12′22″W
# 186      43°49′12″N      79°13′06″W
# 187      43°41′44″N      79°16′33″W
# 188      43°46′44″N      79°08′03″W
# 189      43°49′15″N      79°12′22″W
# 190      43°46′22″N      79°15′27″W
# 191      43°43′00″N      79°15′35″W
# 192      43°44′35″N      79°13′08″W
# 193            None            None
# 194      43°47′17″N      79°18′05″W
# 195      43°46′06″N      79°11′10″W
# 196      43°47′07″N      79°07′33″W
# 197      43°44′35″N      79°18′16″W
# 198      43°46′00″N      79°13′40″W
# 199      43°39′27″N      79°29′33″W
# 200      43°41′44″N      79°27′00″W
# 201      43°41′40″N      79°27′19″W
# 202      43°41′44″N      79°27′00″W
# 203      43°41′28″N      79°25′33″W
# 204      43°39′27″N      79°29′33″W
# 205   43°41′31.14″N   79°30′22.37″W
# 206      43°41′33″N      79°26′27″W
# 207      43°39′08″N      79°29′21″W
# 208      43°40′31″N      79°29′19″W
# 209      43°41′24″N      79°28′34″W
# 210      43°41′23″N      79°28′41″W
# 211    43°42′3.56″N   79°31′10.92″W
#
# [212 rows x 4 columns]

# %%
# Save data as CSV
neigh.to_csv('toronto_neigh.csv')

# %%
print('The dataframe has {} districts and {} neighbourhoods.'.format(
        len(neigh['District'].unique()),
        neigh.shape[0]
    )
)
# Out:
# The dataframe has 6 districts and 212 neighbourhoods.

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Desmond\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     conda-4.6.14               |           py37_0         2.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.19.0               |             py_0          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   geopy              conda-forge/noarch::geopy-1.19.0-py_0
#
# The following packages will be UPDATED:
#
#   conda                      pkgs/main::conda-4.6.11-py37_0 --> conda-forge::conda-4.6.14-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# geographiclib-1.49   | 32 KB     |            |   0%
# geographiclib-1.49   | 32 KB     | #######5   |  75%
# geographiclib-1.49   | 32 KB     | ########## | 100%
#
# certifi-2019.3.9     | 149 KB    |            |   0%
# certifi-2019.3.9     | 149 KB    | ##4        |  24%
# certifi-2019.3.9     | 149 KB    | ########## | 100%
#
# conda-4.6.14         | 2.1 MB    |            |   0%
# conda-4.6.14         | 2.1 MB    | 1          |   1%
# conda-4.6.14         | 2.1 MB    | #2         |  12%
# conda-4.6.14         | 2.1 MB    | ##4        |  24%
# conda-4.6.14         | 2.1 MB    | ###2       |  33%
# conda-4.6.14         | 2.1 MB    | ####2      |  42%
# conda-4.6.14         | 2.1 MB    | #####2     |  52%
# conda-4.6.14         | 2.1 MB    | ######5    |  66%
# conda-4.6.14         | 2.1 MB    | #######6   |  76%
# conda-4.6.14         | 2.1 MB    | ########6  |  86%
# conda-4.6.14         | 2.1 MB    | #########4 |  94%
# conda-4.6.14         | 2.1 MB    | ########## | 100%
#
# geopy-1.19.0         | 53 KB     |            |   0%
# geopy-1.19.0         | 53 KB     | #######5   |  75%
# geopy-1.19.0         | 53 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# D:\Projects\Coursera_Capstone>ET _sysp=%~dpA
#
# D:\Projects\Coursera_Capstone>IF NOT EXIST "!_sysp!\Scripts\conda.exe"
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.11
#   latest version: 4.6.14
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# 'ET' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Get coordinates for Toronto

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="tr_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %% [markdown]
# ## Wrangle data

# %%
df = pd.read_csv('toronto_neigh.csv', index_col=0)

# Convert latitude and longitude to decimals
# When there is no minute
df.loc[df['Latitude'].str.len() == 7, 'Latitude'] = \
    pd.to_numeric(df['Latitude'].str.slice(start=0, stop=2)) + \
    pd.to_numeric(df['Latitude'].str.slice(start=3, stop=5))/60

# When minutes is included
df.loc[df['Latitude'].str.len() > 7, 'Latitude'] = \
    pd.to_numeric(df['Latitude'].str.slice(start=0, stop=2)) + \
    pd.to_numeric(df['Latitude'].str.slice(start=3, stop=5))/60 + \
    np.nan_to_num(pd.to_numeric(df['Latitude'].str.slice(start=6, stop=-2)))/3600

# When there is no minute
df.loc[df['Longitude'].str.len() == 7, 'Longitude'] = \
    - pd.to_numeric(df['Longitude'].str.slice(start=0, stop=2)) - \
    pd.to_numeric(df['Longitude'].str.slice(start=3, stop=5))/60

# When minutes is included
df.loc[df['Longitude'].str.len() > 7, 'Longitude'] = \
    - pd.to_numeric(df['Longitude'].str.slice(start=0, stop=2)) - \
    pd.to_numeric(df['Longitude'].str.slice(start=3, stop=5))/60 - \
    np.nan_to_num(pd.to_numeric(df['Longitude'].str.slice(start=6, stop=-2)))/3600

df.head()
# Out:
#       District    Neighbourhood Latitude Longitude
# 0  Old Toronto   Alexandra Park    43.65     -79.4
# 1  Old Toronto        The Annex    43.67  -79.4039
# 2  Old Toronto  Baldwin Village  43.6561  -79.3933
# 3  Old Toronto      Cabbagetown  43.6664  -79.3628
# 4  Old Toronto        CityPlace    43.64  -79.3953

# %%
# Find NaN coordinates
df[df['Latitude'].isnull()]
# Out:
#         District               Neighbourhood Latitude Longitude
# 9    Old Toronto         Distillery District      NaN       NaN
# 10   Old Toronto  The Entertainment District      NaN       NaN
# 19   Old Toronto             Little Japan[5]      NaN       NaN
# 78   Old Toronto                Little Tibet      NaN       NaN
# 109    Etobicoke                  Humberwood      NaN       NaN
# 193  Scarborough                     Steeles      NaN       NaN

# %%
# Clean Neighbourhood name
df.loc[19]['Neighbourhood'] = df.loc[19]['Neighbourhood'][0:-3]

df.loc[19]
# Out:
# District          Old Toronto
# Neighbourhood    Little Japan
# Latitude                  NaN
# Longitude                 NaN
# Name: 19, dtype: object

# %%
# Get coordinates for missing coordinates
for i, row in df[df['Latitude'].isnull()].iterrows():
    location = geolocator.geocode(row['Neighbourhood'] + ', Toronto, Canada')
    
    if location is not None:
        df.loc[row.name]['Latitude'] = location.latitude
        df.loc[row.name]['Longitude'] = location.longitude

# %%
# Find NaN coordinates
df[df['Latitude'].isnull()]
# Out:
#        District Neighbourhood Latitude Longitude
# 19  Old Toronto  Little Japan      NaN       NaN

# %%
# drop row 19 as location cannot be found
df.drop([19], 0, inplace=True)

# %%
df
# Out:
#         District                                      Neighbourhood Latitude  \
# 0    Old Toronto                                     Alexandra Park    43.65
# 1    Old Toronto                                          The Annex    43.67
# 2    Old Toronto                                    Baldwin Village  43.6561
# 3    Old Toronto                                        Cabbagetown  43.6664
# 4    Old Toronto                                          CityPlace    43.64
# 5    Old Toronto                                          Chinatown  43.6528
# 6    Old Toronto                               Church and Wellesley  43.6657
# 7    Old Toronto                                           Corktown  43.6556
# 8    Old Toronto                                 Discovery District  43.6581
# 9    Old Toronto                                Distillery District  43.6503
# 10   Old Toronto                         The Entertainment District  43.6466
# 11   Old Toronto                                      East Bayfront   43.645
# 12   Old Toronto                                   Fashion District   43.645
# 13   Old Toronto                                 Financial District  43.6479
# 14   Old Toronto                                    Garden District  43.6586
# 15   Old Toronto                                        Grange Park  43.6531
# 16   Old Toronto                                    Harbord Village  43.6611
# 17   Old Toronto                                       Harbourfront  43.6381
# 18   Old Toronto                                  Kensington Market  43.6548
# 20   Old Toronto                                          Moss Park  43.6558
# 21   Old Toronto                                           Old Town  43.6514
# 22   Old Toronto                                           Quayside  43.6469
# 23   Old Toronto                                  Queen Street West  43.6497
# 24   Old Toronto                                        Regent Park  43.6617
# 25   Old Toronto                                         South Core  43.6439
# 26   Old Toronto                                     St. James Town  43.6692
# 27   Old Toronto                                       St. Lawrence  43.6489
# 28   Old Toronto                                    Toronto Islands  43.6208
# 29   Old Toronto                                      Trefann Court  43.6567
# 30   Old Toronto                 University (includes Huron–Sussex)  43.6617
# ..           ...                                                ...      ...
# 182  Scarborough                                            Malvern  43.8117
# 183  Scarborough                                           Maryvale  43.7431
# 184  Scarborough                                           Milliken  43.8258
# 185  Scarborough                                        Morningside  43.7869
# 186  Scarborough                                Morningside Heights    43.82
# 187  Scarborough                                           Oakridge  43.6956
# 188  Scarborough                Port Union (Centennial Scarborough)  43.7789
# 189  Scarborough                                              Rouge  43.8208
# 190  Scarborough                            Scarborough City Centre  43.7728
# 191  Scarborough                               Scarborough Junction  43.7167
# 192  Scarborough                                Scarborough Village  43.7431
# 193  Scarborough                                            Steeles  43.8162
# 194  Scarborough                           Tam O'Shanter – Sullivan  43.7881
# 195  Scarborough                                          West Hill  43.7683
# 196  Scarborough                                         West Rouge  43.7853
# 197  Scarborough                                            Wexford  43.7431
# 198  Scarborough                                             Woburn  43.7667
# 199         York                                         Baby Point  43.6575
# 200         York                               Briar Hill–Belgravia  43.6956
# 201         York                     Eglinton West (Little Jamaica)  43.6944
# 202         York                      Fairbank (Caledonia–Fairbank)  43.6956
# 203         York                                 Humewood–Cedarvale  43.6911
# 204         York                                            Lambton  43.6575
# 205         York                                       Mount Dennis   43.692
# 206         York  Oakwood–Vaughan (Oakwood Village; Five Points;...  43.6925
# 207         York                                           Old Mill  43.6522
# 208         York                                  Rockcliffe–Smythe  43.6753
# 209         York                           Silverthorn (Keelesdale)    43.69
# 210         York                                          Tichester  43.6897
# 211         York                                             Weston   43.701
#
#     Longitude
# 0       -79.4
# 1    -79.4039
# 2    -79.3933
# 3    -79.3628
# 4    -79.3953
# 5    -79.3981
# 6     -79.381
# 7    -79.3597
# 8    -79.3881
# 9    -79.3595
# 10   -79.3897
# 11   -79.3647
# 12   -79.3981
# 13   -79.3818
# 14   -79.3758
# 15   -79.3931
# 16   -79.4061
# 17    -79.385
# 18   -79.4007
# 20   -79.3672
# 21   -79.3678
# 22   -79.3617
# 23   -79.3925
# 24    -79.365
# 25   -79.3794
# 26   -79.3728
# 27   -79.3719
# 28   -79.3786
# 29   -79.3619
# 30    -79.395
# ..        ...
# 182  -79.2311
# 183  -79.3044
# 184  -79.3008
# 185  -79.2061
# 186  -79.2183
# 187  -79.2758
# 188  -79.1342
# 189  -79.2061
# 190  -79.2575
# 191  -79.2597
# 192  -79.2189
# 193  -79.3145
# 194  -79.3014
# 195  -79.1861
# 196  -79.1258
# 197  -79.3044
# 198  -79.2278
# 199  -79.4925
# 200    -79.45
# 201  -79.4553
# 202    -79.45
# 203  -79.4258
# 204  -79.4925
# 205  -79.5062
# 206  -79.4408
# 207  -79.4892
# 208  -79.4886
# 209  -79.4761
# 210  -79.4781
# 211  -79.5197
#
# [211 rows x 4 columns]

# %%
# Find NaN coordinates
df[df['Latitude'].isnull()]
# Out:
# Empty DataFrame
# Columns: [District, Neighbourhood, Latitude, Longitude]
# Index: []

# %%
df.to_csv('toronto_neigh_clean.csv')

# %% [markdown]
# ## Create map

# %%
# !conda install -c conda-forge folium -y
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import folium

df = pd.read_csv('toronto_neigh_clean.csv')
map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers
for lat, lng, district, neighbourhood in zip(df['Latitude'], df['Longitude'], df['District'], df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json

# import foursquare credentials
with open('credentials.json') as f:
    data = json.load(f)
    CLIENT_ID = data['CLIENT_ID']
    CLIENT_SECRET = data['CLIENT_SECRET']
    VERSION = '20190519'

# %%
CLIENT_SECRET
# Out:
# 'EFW23EHMB5WYDHS1ZSLQ32F51WJSXRHGWYTMPFKCBC5QOCXC'
